# %%
# Nguyễn Hữu Thâu - 19146265
# MSSV: 19146265
# Lớp chiều thứ 5, tiết 10-12

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.datasets import mnist, fashion_mnist, cifar10, cifar100
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from keras.utils import np_utils
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_history(history_fine):
  f1 = history_fine.history['acc']
  val_f1 = history_fine.history['val_acc']

  loss = history_fine.history['loss']
  val_loss = history_fine.history['val_loss']

  plt.figure(figsize=(8, 8))
  plt.subplot(2, 1, 1)
  plt.plot(f1, label='Acc')
  plt.plot(val_f1, label='Validation Acc')
  plt.legend(loc='lower right')
  plt.title('Accuracy')

  plt.subplot(2, 1, 2)
  plt.plot(loss, label='Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Loss')
  plt.xlabel('epoch')
  plt.show()

# %%
# Load Data
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_pre = x_test[0]
y_pre = y_test[0]

# Reshape Data
x_train = x_train.reshape(x_train.shape[0], -1)
x_test = x_test.reshape(x_test.shape[0], -1)

# Preprocessing Data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Encoding Y
y_train = np_utils.to_categorical(y_train, 10)
y_test = np_utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_shape = (784,)))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer =Adam(), metrics=['acc'])

history = model.fit(x_train, y_train, batch_size = 128, epochs = 5, validation_split = 0.2)

plot_history(history)
# Out:
# Epoch 1/5
# 375/375 [==============================] - 6s 8ms/step - loss: 1.0161 - acc: 0.6605 - val_loss: 0.6188 - val_acc: 0.7843
# Epoch 2/5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.5639 - acc: 0.8041 - val_loss: 0.5350 - val_acc: 0.8119
# Epoch 3/5
# 375/375 [==============================] - 3s 7ms/step - loss: 0.5068 - acc: 0.8233 - val_loss: 0.5108 - val_acc: 0.8193
# Epoch 4/5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4799 - acc: 0.8320 - val_loss: 0.4824 - val_acc: 0.8302
# Epoch 5/5
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4634 - acc: 0.8377 - val_loss: 0.4829 - val_acc: 0.8288

# %%
model1 = Sequential()
model1.add(Dense(10, activation='relu', input_shape = (784,)))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(10, activation='relu'))
model1.add(Dense(10, activation='softmax'))

model1.compile(loss='categorical_crossentropy', optimizer =Adam(), metrics=['acc'])

history1 = model1.fit(x_train, y_train, batch_size = 128, epochs = 5, validation_split = 0.2)

plot_history(history1)
# Out:
# Epoch 1/5
# 375/375 [==============================] - 3s 5ms/step - loss: 1.2807 - acc: 0.5095 - val_loss: 0.7765 - val_acc: 0.7259
# Epoch 2/5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.6449 - acc: 0.7721 - val_loss: 0.5639 - val_acc: 0.8066
# Epoch 3/5
# 375/375 [==============================] - 3s 7ms/step - loss: 0.5433 - acc: 0.8108 - val_loss: 0.5367 - val_acc: 0.8105
# Epoch 4/5
# 375/375 [==============================] - 3s 8ms/step - loss: 0.5121 - acc: 0.8192 - val_loss: 0.5062 - val_acc: 0.8233
# Epoch 5/5
# 375/375 [==============================] - 3s 9ms/step - loss: 0.5001 - acc: 0.8237 - val_loss: 0.4925 - val_acc: 0.8266

# %%
model2 = Sequential()
model2.add(Dense(10, activation='relu', input_shape = (784,)))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='relu'))
model2.add(Dense(10, activation='softmax'))

model2.compile(loss='categorical_crossentropy', optimizer =Adam(), metrics=['acc'])

history2 = model2.fit(x_train, y_train, batch_size = 128, epochs = 5, validation_split = 0.2)

plot_history(history2)
# Out:
# Epoch 1/5
# 375/375 [==============================] - 4s 6ms/step - loss: 1.6598 - acc: 0.3638 - val_loss: 1.0133 - val_acc: 0.6395
# Epoch 2/5
# 375/375 [==============================] - 3s 8ms/step - loss: 0.8005 - acc: 0.7035 - val_loss: 0.6837 - val_acc: 0.7632
# Epoch 3/5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.6262 - acc: 0.7791 - val_loss: 0.6027 - val_acc: 0.7879
# Epoch 4/5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.5644 - acc: 0.7945 - val_loss: 0.5905 - val_acc: 0.7832
# Epoch 5/5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.5339 - acc: 0.8048 - val_loss: 0.6008 - val_acc: 0.7932

# %%
loss_dict = {
  "1-10": history.history['val_acc'],
  "5-10": history1.history['val_acc'],
  "10-10": history2.history['val_acc']
}

# %%
# plot error bar
x = []
y = []
yerr = []
for k, v in loss_dict.items():
    x.append(k)
    y.append(np.mean(v))  # compute mean
    yerr.append([np.mean(v) - min(v), max(v) - np.mean(v)])  # use max and min as upper and lower bound

yerr = np.transpose(yerr)  # yerr should be 2xN matrix
plt.errorbar(x, y, yerr=yerr, color='r')
plt.xlabel("Models_Architecture")
plt.ylabel('value')
plt.title("Val_Accuracy")
plt.grid(b=True, color='g')
plt.show()

# %%
Fashion_Mnist_Label = ["T-shirt", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
plt.title("Model 1 Hidden và 10 Neuron dự đoán là: " + str(Fashion_Mnist_Label[np.argmax(model.predict(x_pre.reshape((-1,28*28))))]))
plt.imshow(x_pre, cmap=plt.get_cmap('gray'))
